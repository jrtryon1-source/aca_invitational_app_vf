# %%
import streamlit as st
import pandas as pd
import numpy as np

# %%
if "results" not in st.session_state:
    st.session_state["results"] = pd.DataFrame(columns=[
        "round", "aff_team", "neg_team", "winner", "judge", "aff_speaks", "neg_speaks"
    ])
